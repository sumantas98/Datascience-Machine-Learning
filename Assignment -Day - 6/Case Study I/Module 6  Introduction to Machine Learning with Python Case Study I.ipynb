# %% [markdown]
# <font size="5"><b>Case Study I</b><br><br>
# Module 6  Introduction to Machine Learning with Python
#  </font>

# %% [markdown]
# <font color='red'>
# Objective:<br><br>
# 1. Make the learner load the data using pandas.<br>
# 2. Create new columns in dataset from existing columns.<br>
# 3. Use pandas to answer questions of interest.<br>
# 4. Plot variables of interest.<br>
# Dataset used: Prisoners dataset sourced from data.gov.in<br><br>
#
# Questions:<br><br>
# 1. Data Loading:<br>
# a. Load the dataset “prisoners.csv” using pandas and display the first and
# last five rows in the dataset.
# [Hint: Refer to read_csv, head and tail methods in pandas]<br>
# b. Use describe method in pandas and find out the number of columns. Can
# you say something about those rows who have zero inmates?
# [Hint: Use the loc attribute of dataframe combined with conditional
# checks]<br><br>
# 2. Data Manipulation:<br>
# a. Create a new column -’total_benefitted’ that is a sum of inmates
# benefitted through all modes.<br>
# [Hint: Use sum method with appropriate axis]<br>
# b. Create a new row - “totals” that is the sum of all inmates benefitted
# through each mode across all states.<br><br>
# 3. Plotting:<br><br>
# a. Make a bar plot with each state name on the x -axis and their total
# benefitted inmates as their bar heights. Which state has the maximum
# number of beneficiaries?
# [Hint: Use bar method of pyplot]<br>
# b. Make a pie chart that depicts the ratio among different modes of
# benefits.
# [Hint: Use pie method of pyplot]
# </font>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sn

# %%
rd = pd.read_csv('prisoners.csv')
print(rd.head(5))

print(rd.tail(5))
# Out:
#             STATE/UT  YEAR  No. of Inmates benefitted by Elementary Education  \
# 0     Andhra Pradesh  2013                                               9480
# 1  Arunachal Pradesh  2013                                                  0
# 2              Assam  2013                                                676
# 3              Bihar  2013                                               1693
# 4        Chhatisgarh  2013                                               1664
#
#    No. of Inmates benefitted by Adult Education  \
# 0                                         13758
# 1                                             0
# 2                                           750
# 3                                          3013
# 4                                          1803
#
#    No. of Inmates benefitted by Higher Education  \
# 0                                            672
# 1                                              0
# 2                                             14
# ...

# %%
rd.describe()

len(rd.columns)
# Out:
# 6

# %% [markdown]
# rd

# %%
rd.loc[(rd['No. of Inmates benefitted by Elementary Education']==0) & (rd['No. of Inmates benefitted by Adult Education']==0)]
# Out:
#              STATE/UT  YEAR  \
# 1   Arunachal Pradesh  2013
# 15            Manipur  2013
# 18           Nagaland  2013
# 22             Sikkim  2013
# 30       D & N Haveli  2013
# 31        Daman & Diu  2013
# 33        Lakshadweep  2013
# 34        Pondicherry  2013
#
#     No. of Inmates benefitted by Elementary Education  \
# 1                                                   0
# 15                                                  0
# 18                                                  0
# 22                                                  0
# 30                                                  0
# 31                                                  0
# 33                                                  0
# 34                                                  0
#
#     No. of Inmates benefitted by Adult Education  \
# 1                                              0
# 15                                             0
# 18                                             0
# ...

# %%
total_benefitted=rd.iloc[:,2:6].sum(axis=1,skipna = True)

# %%
rd['total_benefitted']=total_benefitted
rd
# Out:
#              STATE/UT  YEAR  \
# 0      Andhra Pradesh  2013
# 1   Arunachal Pradesh  2013
# 2               Assam  2013
# 3               Bihar  2013
# 4         Chhatisgarh  2013
# 5                 Goa  2013
# 6             Gujarat  2013
# 7             Haryana  2013
# 8    Himachal Pradesh  2013
# 9     Jammu & Kashmir  2013
# 10          Jharkhand  2013
# 11          Karnataka  2013
# 12             Kerala  2013
# 13     Madhya Pradesh  2013
# 14        Maharashtra  2013
# 15            Manipur  2013
# 16          Meghalaya  2013
# 17            Mizoram  2013
# 18           Nagaland  2013
# 19             Orissa  2013
# 20             Punjab  2013
# 21          Rajasthan  2013
# 22             Sikkim  2013
# 23          Tamilnadu  2013
# 24            Tripura  2013
# 25      Uttar Pradesh  2013
# 26        Uttaranchal  2013
# 27        West Bengal  2013
# 28      A & N Islands  2013
# 29         Chandigarh  2013
# 30       D & N Haveli  2013
# 31        Daman & Diu  2013
# ...

# %%
total=rd.iloc[:,2:7].sum(axis=0,skipna = True)

# %%
total
# Out:
# No. of Inmates benefitted by Elementary Education     37027
# No. of Inmates benefitted by Adult Education          53720
# No. of Inmates benefitted by Higher Education          8311
# No. of Inmates benefitted by Computer Course           7356
# total_benefitted                                     106414
# dtype: int64

# %%
df=pd.DataFrame(total)

# %%
rd.loc[35]=total

# %%
rd
# Out:
#              STATE/UT    YEAR  \
# 0      Andhra Pradesh  2013.0
# 1   Arunachal Pradesh  2013.0
# 2               Assam  2013.0
# 3               Bihar  2013.0
# 4         Chhatisgarh  2013.0
# 5                 Goa  2013.0
# 6             Gujarat  2013.0
# 7             Haryana  2013.0
# 8    Himachal Pradesh  2013.0
# 9     Jammu & Kashmir  2013.0
# 10          Jharkhand  2013.0
# 11          Karnataka  2013.0
# 12             Kerala  2013.0
# 13     Madhya Pradesh  2013.0
# 14        Maharashtra  2013.0
# 15            Manipur  2013.0
# 16          Meghalaya  2013.0
# 17            Mizoram  2013.0
# 18           Nagaland  2013.0
# 19             Orissa  2013.0
# 20             Punjab  2013.0
# 21          Rajasthan  2013.0
# 22             Sikkim  2013.0
# 23          Tamilnadu  2013.0
# 24            Tripura  2013.0
# 25      Uttar Pradesh  2013.0
# 26        Uttaranchal  2013.0
# 27        West Bengal  2013.0
# 28      A & N Islands  2013.0
# 29         Chandigarh  2013.0
# ...

# %%
#plt.bar(x=np.arange(1,34),height=rd['total_benefitted'])
#x=np.arange(len(rd['STATE/UT'])-1)
p=rd.head(35)

plt.bar(x=np.arange(len(p['STATE/UT'])),height=p['total_benefitted'])
plt.title('STATE/UT  Vs  total_benefitted')
plt.xlabel('STATE/UT')
plt.ylabel('total_benefitted')

plt.xticks(np.arange(0,34),p['STATE/UT'], rotation=90)
plt.show()

# %%
rd
# Out:
#              STATE/UT    YEAR  \
# 0      Andhra Pradesh  2013.0
# 1   Arunachal Pradesh  2013.0
# 2               Assam  2013.0
# 3               Bihar  2013.0
# 4         Chhatisgarh  2013.0
# 5                 Goa  2013.0
# 6             Gujarat  2013.0
# 7             Haryana  2013.0
# 8    Himachal Pradesh  2013.0
# 9     Jammu & Kashmir  2013.0
# 10          Jharkhand  2013.0
# 11          Karnataka  2013.0
# 12             Kerala  2013.0
# 13     Madhya Pradesh  2013.0
# 14        Maharashtra  2013.0
# 15            Manipur  2013.0
# 16          Meghalaya  2013.0
# 17            Mizoram  2013.0
# 18           Nagaland  2013.0
# 19             Orissa  2013.0
# 20             Punjab  2013.0
# 21          Rajasthan  2013.0
# 22             Sikkim  2013.0
# 23          Tamilnadu  2013.0
# 24            Tripura  2013.0
# 25      Uttar Pradesh  2013.0
# 26        Uttaranchal  2013.0
# 27        West Bengal  2013.0
# 28      A & N Islands  2013.0
# 29         Chandigarh  2013.0
# ...

# %%
total=rd.iloc[:,2:6].sum(axis=0,skipna = True)

# %%
label=rd.columns

# %%
y=(total)
x=(label[2:6])
plt.pie(y,labels=x)
plt.show()
